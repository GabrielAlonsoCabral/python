# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns 
pd.plotting.register_matplotlib_converters()
print('Setup Complete')
# Out:
# Setup Complete

# %%
df=pd.read_csv('flight_delays.csv',index_col='Month')
df.head()
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
#
#              HA         MQ         NK         OO        UA        US  \
# Month
# 1      3.512640  18.164974  11.398054  10.889894  6.352729  3.107457
# 2      6.029967  21.301627  16.474466   9.588895  7.260662  7.114455
# 3      3.468383  11.018418  10.039118   3.181693  4.892212  3.330787
# 4      0.011022   5.131228   8.766224   3.223796  4.376092  2.660290
# 5      0.826426   5.466790  22.397347   4.141162  6.827695  0.681605
#
#              VX        WN
# Month
# 1      1.420702  3.389466
# 2      7.784410  3.501363
# 3      5.348207  3.263341
# ...

# %%
df.describe()
# Out:
#               AA         AS         B6         DL         EV         F9  \
# count  12.000000  12.000000  12.000000  12.000000  12.000000  12.000000
# mean    4.120776  -1.023656   6.788370   0.231116   6.543328  13.035736
# std     3.157890   1.544310   5.543460   3.247467   3.506834   7.844315
# min    -1.432732  -3.009003  -0.709019  -5.011516   0.851062   0.082127
# 25%     2.588588  -1.864140   3.349392  -2.326739   4.719922   9.303600
# 50%     4.540731  -1.249661   5.444304   0.401224   6.707638  12.823997
# 75%     6.759151  -0.295821   9.646042   2.184623   7.927592  18.696167
# max     8.191017   2.503899  18.657673   5.614745  13.952793  27.424179
#
#               HA         MQ         NK         OO         UA        US  \
# count  12.000000  12.000000  12.000000  12.000000  12.000000  6.000000
# mean    1.993205   5.964953  14.549663   5.909658   5.413415  3.776815
# std     2.987726   7.780334   8.319500   3.380527   5.281123  2.305290
# ...

# %%
plt.figure(figsize=(10,6))
empresa=input('Digite a empresa:')
sigla=input('Digite a sigla da empresa em maiusculo:')
plt.title('Average Arrival Delay for %s, by Month'%empresa)
plt.ylabel('Arrival delays(in minutes)')
#sns.LINEplot ----> (line-bar)plot
sns.barplot(x=df.index,y=df['%s'%sigla])
#index foi defiinido anteriormente como Month--->logo, df.index refere-se ao eixo x como month
#df['']refere-se a empresa que será estudada no eixo y, sua taxa de atrasado ao mes.

plt.ylabel('Arrival delays(in minutes)')
# Out:
# Digite a empresa:American Airlines
# Digite a sigla da empresa em maiusculo:AA
# Text(0, 0.5, 'Arrival delays(in minutes)')

# %%
plt.figure(figsize=(14,6))
plt.title('Average arrival delays for each airline(in minutes), by month')
sns.heatmap(data=df,annot=True)
#annot permite a visualização númerica relativo ao color
# Out:
# <AxesSubplot:title={'center':'Average arrival delays for each airline(in minutes), by month'}, ylabel='Month'>

# %%
## Exercicios

# %%
df2=pd.read_csv('ign_scores.csv',index_col='Platform')

# %%
df2.head(20)
# Out:
#                 Platform    Action  Action, Adventure  Adventure  Fighting  \
# 0              Dreamcast  6.882857           7.511111   6.281818  8.200000
# 1       Game Boy Advance  6.373077           7.507692   6.057143  6.226316
# 2         Game Boy Color  6.272727           8.166667   5.307692  4.500000
# 3               GameCube  6.532584           7.608333   6.753846  7.422222
# 4           Nintendo 3DS  6.670833           7.481818   7.414286  6.614286
# 5            Nintendo 64  6.649057           8.250000   7.000000  5.681250
# 6            Nintendo DS  5.903608           7.240000   6.259804  6.320000
# 7           Nintendo DSi  6.827027           8.500000   6.090909  7.500000
# 8                     PC  6.805791           7.334746   7.136798  7.166667
# 9            PlayStation  6.016406           7.933333   6.313725  6.553731
# 10         PlayStation 2  6.467361           7.250000   6.315152  7.306349
# ...

# %%
plt.figure(figsize=(35,15))
plt.title('Average scores')
sns.barplot(x=df2.index,y=df2['Racing'])
# Out:
# <AxesSubplot:title={'center':'Average scores'}, xlabel='Platform', ylabel='Racing'>

# %%
plt.figure(figsize=(10,6))
plt.title('Average Scores for racing, by platform')
sns.heatmap(data=df2,annot=True)
# Out:
# <AxesSubplot:title={'center':'Average Scores for racing, by platform'}, ylabel='Platform'>
