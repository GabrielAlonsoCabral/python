# %%
import pandas as pd
df=pd.read_csv('winemag-data-130k-v2.csv')
#conta a quantidade de pontos respectivos
df.groupby('price').points.count()
# Out:
# price
# 4.0        11
# 5.0        46
# 6.0       120
# 7.0       433
# 8.0       892
#          ...
# 1900.0      1
# 2000.0      2
# 2013.0      1
# 2500.0      2
# 3300.0      1
# Name: points, Length: 390, dtype: int64

# %%
df.head(5)
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
df.groupby('points').price.min()
#df.groupby('coluna1').coluna2.desejo()
df.groupby('points').price.max()
# Out:
# points
# 80       69.0
# 81      130.0
# 82      150.0
# 83      225.0
# 84      225.0
# 85      320.0
# 86      170.0
# 87      800.0
# 88     3300.0
# 89      500.0
# 90      510.0
# 91     2013.0
# 92      750.0
# 93      770.0
# 94     1125.0
# 95      973.0
# 96     2500.0
# 97     2000.0
# 98     1900.0
# 99      850.0
# 100    1500.0
# Name: price, dtype: float64

# %%
df.loc[(df['points']==100) & (df['price']==80)]
# Out:
#         Unnamed: 0 country                                        description  \
# 113929      113929      US  In 2005 Charles Smith introduced three high-en...
# 123545      123545      US  Initially a rather subdued Frog; as if it has ...
#
#         designation  points  price    province                 region_1  \
# 113929   Royal City     100   80.0  Washington     Columbia Valley (WA)
# 123545  Bionic Frog     100   80.0  Washington  Walla Walla Valley (WA)
#
#                region_2   taster_name taster_twitter_handle  \
# 113929  Columbia Valley  Paul Gregutt           @paulgwine
# 123545  Columbia Valley  Paul Gregutt           @paulgwine
#
#                                                     title variety  \
# 113929  Charles Smith 2006 Royal City Syrah (Columbia ...   Syrah
# 123545  Cayuse 2008 Bionic Frog Syrah (Walla Walla Val...   Syrah
#
#                winery
# 113929  Charles Smith
# 123545         Cayuse

# %%
df.groupby('country').price.agg(['std','max','min'])
# Out:
#                               std     max   min
# country
# Argentina               23.430122   230.0   4.0
# Armenia                  0.707107    15.0  14.0
# Australia               49.049458   850.0   5.0
# Austria                 27.224797  1100.0   7.0
# Bosnia and Herzegovina   0.707107    13.0  12.0
# Brazil                  11.053649    60.0  10.0
# Bulgaria                 9.508744   100.0   8.0
# Canada                  19.658148   120.0  12.0
# Chile                   21.929371   400.0   5.0
# China                         NaN    18.0  18.0
# Croatia                 12.993173    65.0  12.0
# Cyprus                   2.831639    21.0  11.0
# Czech Republic          12.053856    45.0  15.0
# Egypt                         NaN     NaN   NaN
# England                 14.858641    95.0  25.0
# France                  73.769404  3300.0   5.0
# Georgia                  7.642873    40.0   9.0
# Germany                 62.860308   775.0   5.0
# ...

# %%
df.loc[df['country']=='Brazil']
# Out:
#         Unnamed: 0 country                                        description  \
# 5852          5852  Brazil  Pear, apple and wet-stone aromas are tight, wh...
# 9151          9151  Brazil  This opens with dusty dried-apple aromas. High...
# 10565        10565  Brazil  The name is appropriate: this is intense, just...
# 10579        10579  Brazil  Roasted gritty aromas of asphalt and grilled b...
# 12669        12669  Brazil  This Cabernet Sauvignon-Merlot blend almost ha...
# 13218        13218  Brazil  This leesy, bready, heavily toasted Brazilian ...
# 14726        14726  Brazil  Bell pepper and sharp red fruit aromas provide...
# 14734        14734  Brazil  A weird Cabernet with unfamiliar, odd aromas. ...
# 14739        14739  Brazil  Sketchy right away, with salinic, pool water a...
# 15989        15989  Brazil  Aromas of lemon-lime and lemon-scented househo...
# 20987        20987  Brazil  A dark salmon color and yeasty soapy aromas an...
# ...

# %%
df.groupby('taster_twitter_handle').taster_name.max()
# Out:
# taster_twitter_handle
# @AnneInVino          Anne Krebiehl MW
# @JoeCz                 Joe Czerwinski
# @bkfiona                  Fiona Adams
# @gordone_cellars           Jim Gordon
# @kerinokeefe            Kerin O’Keefe
# @laurbuzz               Lauren Buzzeo
# @mattkettmann           Matt Kettmann
# @paulgwine               Paul Gregutt
# @suskostrzewa         Susan Kostrzewa
# @vboone                Virginie Boone
# @vossroger                 Roger Voss
# @wawinereport        Sean P. Sullivan
# @wineschach         Michael Schachner
# @winewchristina     Christina Pickard
# @worldwineguys          Mike DeSimone
# Name: taster_name, dtype: object

# %%
df.groupby(['country','points']).price.agg(['min','std','max'])
# Out:
#                    min        std    max
# country   points
# Argentina 80       5.0   4.768905   35.0
#           81       6.0   5.830481   37.0
#           82       6.0   5.889708   34.0
#           83       6.0   8.936930  125.0
#           84       4.0   6.233485   64.0
# ...                ...        ...    ...
# Uruguay   88      13.0  23.424852  120.0
#           89      16.0  13.076697   52.0
#           90      20.0  33.955854  130.0
#           91      22.0  16.375795   60.0
#           92      43.0   0.000000   43.0
#
# [463 rows x 3 columns]

# %%
df.groupby(['variety','points']).price.agg(['min','max'])
# Out:
#                      min   max
# variety     points
# Abouriou    85      75.0  75.0
#             87      15.0  15.0
#             91      15.0  15.0
# Agiorgitiko 83      13.0  13.0
#             84      12.0  17.0
# ...                  ...   ...
# Zweigelt    93      50.0  50.0
#             94      35.0  35.0
# Çalkarası   86      19.0  19.0
#             87      19.0  19.0
# Žilavka     88      15.0  15.0
#
# [4062 rows x 2 columns]

# %%
mylist=df.groupby('variety').price.agg(['max','min'])
mylist.sort_values('variety',ascending=True)
# Out:
#                max   min
# variety
# Abouriou      75.0  15.0
# Agiorgitiko   66.0  10.0
# Aglianico    180.0   6.0
# Aidani        27.0  27.0
# Airen         10.0   8.0
# ...            ...   ...
# Zinfandel    100.0   5.0
# Zlahtina      16.0  13.0
# Zweigelt      70.0   9.0
# Çalkarası     19.0  19.0
# Žilavka       15.0  15.0
#
# [707 rows x 2 columns]

# %%
df.groupby('taster_name').points.mean()
# Out:
# taster_name
# Alexander Peartree    85.855422
# Anna Lee C. Iijima    88.415629
# Anne Krebiehl MW      90.562551
# Carrie Dykes          86.395683
# Christina Pickard     87.833333
# Fiona Adams           86.888889
# Jeff Jenssen          88.319756
# Jim Gordon            88.626287
# Joe Czerwinski        88.536235
# Kerin O’Keefe         88.867947
# Lauren Buzzeo         87.739510
# Matt Kettmann         90.008686
# Michael Schachner     86.907493
# Mike DeSimone         89.101167
# Paul Gregutt          89.082564
# Roger Voss            88.708003
# Sean P. Sullivan      88.755739
# Susan Kostrzewa       86.609217
# Virginie Boone        89.213379
# Name: points, dtype: float64

# %%
k=df.groupby(['country','variety']).variety.count()
k.head(1200)
# Out:
# country    variety
# Argentina  Barbera                         1
#            Bonarda                       105
#            Bordeaux-style Red Blend       89
#            Bordeaux-style White Blend      1
#            Cabernet Blend                  8
#                                         ...
# Spain      Cariñena-Garnacha               2
#            Champagne Blend                13
#            Chardonnay                     74
#            Chardonnay-Sauvignon Blanc      1
#            Doña Blanca                     1
# Name: variety, Length: 1200, dtype: int64
