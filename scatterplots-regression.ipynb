# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
print('setup complete')
# Out:
# setup complete

# %%
df=pd.read_csv('insurance.csv')

# %%
df.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
sns.scatterplot(x=df['bmi'],y=df['charges'])
#bmi entre 18.5 e 24.9 é considerado normal nos estados unidos, acima já é acima do peso
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
#o plot acima sugere que o IMC (indice de massa corporal) está relacionada a suas cobranças

# %%
df.sex.value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
sns.scatterplot(x=df['region'],y=df['charges'])
# Out:
# <AxesSubplot:xlabel='region', ylabel='charges'>

# %%
sns.scatterplot(x=df['age'],y=df['charges'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='charges'>

# %%
sns.scatterplot(x=df['children'],y=df['charges'])
# Out:
# <AxesSubplot:xlabel='children', ylabel='charges'>

# %%
df.children.value_counts()
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
df.groupby('children').charges.agg(['max','min','mean'])
# Out:
#                   max        min          mean
# children
# 0         63770.42801  1121.8739  12365.975602
# 1         58571.07448  1711.0268  12731.171832
# 2         49577.66240  2304.0022  15073.563734
# 3         60021.39897  3443.0640  15355.318367
# 4         40182.24600  4504.6624  13850.656311
# 5         19023.26000  4687.7970   8786.035247

# %%
#a tabela acima implica numa curva de sino.

# %%
sns.scatterplot(x=df['bmi'],y=df['charges'],hue=df['smoker'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
#pessoas possuem menos problemas de créditos

# %%
sns.regplot(x=df['bmi'],y=df['charges'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
sns.lmplot(x='bmi',y='charges',hue='smoker',data=df)

# %%
df2=pd.read_csv('candy.csv')

# %%
df2.head(100)
# Out:
#     id              competitorname chocolate fruity caramel peanutyalmondy  \
# 0    0                   100 Grand       Yes     No     Yes             No
# 1    1                3 Musketeers       Yes     No      No             No
# 2    2                   Air Heads        No    Yes      No             No
# 3    3                  Almond Joy       Yes     No      No            Yes
# 4    4                   Baby Ruth       Yes     No     Yes            Yes
# ..  ..                         ...       ...    ...     ...            ...
# 78  78                   Twizzlers        No    Yes      No             No
# 79  79                    Warheads        No    Yes      No             No
# 80  80        Welch's Fruit Snacks        No    Yes      No             No
# 81  81  Werther's Original Caramel        No     No     Yes             No
# 82  82                    Whoppers       Yes     No      No             No
#
# ...

# %%
sns.scatterplot(x=df2['caramel'],y=df2['winpercent'])
# Out:
# <AxesSubplot:xlabel='caramel', ylabel='winpercent'>

# %%
df2.loc[df2['competitorname']=='3 Musketeers']
# Out:
#    id competitorname chocolate fruity caramel peanutyalmondy nougat  \
# 1   1   3 Musketeers       Yes     No      No             No    Yes
#
#   crispedricewafer hard  bar pluribus  sugarpercent  pricepercent  winpercent
# 1               No   No  Yes       No         0.604         0.511   67.602936

# %%
sns.scatterplot(x=df2['pricepercent'],y=df2['winpercent'],hue=df2['chocolate'])
# Out:
# <AxesSubplot:xlabel='pricepercent', ylabel='winpercent'>

# %%
sns.lmplot(x='pricepercent',y='winpercent',hue='chocolate',data=df2)

# %%
sns.scatterplot(x=df2['chocolate'],y=df2['winpercent'])
# Out:
# <AxesSubplot:xlabel='chocolate', ylabel='winpercent'>
