# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("#########Setup Complete###########")
# Out:
# #########Setup Complete###########

# %%
df1=pd.read_csv('fifa.csv',index_col='Date', parse_dates=True)
df1.head(100)
df1.describe()
# Out:
#               ARG         BRA         ESP         FRA         GER         ITA
# count  286.000000  286.000000  286.000000  286.000000  286.000000  286.000000
# mean     5.454545    3.171329    5.321678    8.958042    5.104895    8.353147
# std      4.012659    3.620897    3.908787    6.822948    4.354813    4.514822
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      3.000000    1.000000    2.000000    3.000000    2.000000    4.000000
# 50%      5.000000    1.500000    5.000000    7.000000    4.000000    8.000000
# 75%      7.000000    4.000000    8.000000   15.000000    5.000000   12.000000
# max     24.000000   22.000000   25.000000   27.000000   22.000000   20.000000

# %%
df1.describe()
# Out:
#               ARG         BRA         ESP         FRA         GER         ITA
# count  286.000000  286.000000  286.000000  286.000000  286.000000  286.000000
# mean     5.454545    3.171329    5.321678    8.958042    5.104895    8.353147
# std      4.012659    3.620897    3.908787    6.822948    4.354813    4.514822
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      3.000000    1.000000    2.000000    3.000000    2.000000    4.000000
# 50%      5.000000    1.500000    5.000000    7.000000    4.000000    8.000000
# 75%      7.000000    4.000000    8.000000   15.000000    5.000000   12.000000
# max     24.000000   22.000000   25.000000   27.000000   22.000000   20.000000

# %%
plt.figure(figsize=(16,6))
sns.lineplot(data=df1)
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
## parte 2

# %%
df2=pd.read_csv('spotify.csv', index_col='Date', parse_dates=True)
df2.rename(columns={'HUMBLE.':'HUMBLE'})
# Out:
#             Shape of You  Despacito  Something Just Like This     HUMBLE  \
# Date
# 2017-01-06      12287078        NaN                       NaN        NaN
# 2017-01-07      13190270        NaN                       NaN        NaN
# 2017-01-08      13099919        NaN                       NaN        NaN
# 2017-01-09      14506351        NaN                       NaN        NaN
# 2017-01-10      14275628        NaN                       NaN        NaN
# ...                  ...        ...                       ...        ...
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# ...

# %%
df2.head(100)
# Out:
#             Shape of You  Despacito  Something Just Like This     HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN         NaN
# 2017-01-07      13190270        NaN                       NaN         NaN
# 2017-01-08      13099919        NaN                       NaN         NaN
# 2017-01-09      14506351        NaN                       NaN         NaN
# 2017-01-10      14275628        NaN                       NaN         NaN
# ...                  ...        ...                       ...         ...
# 2017-04-11      11736951  5877897.0                 8591469.0   7468021.0
# 2017-04-12      11716914  6041766.0                 8590463.0   7495873.0
# 2017-04-13      11958775  6327822.0                 8553816.0   7573209.0
# 2017-04-14      11443718  5846681.0                 8048741.0  13144962.0
# 2017-04-15      11042206  5617332.0                 7450464.0  11963789.0
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# ...

# %%
plt.figure(figsize=(16,6))
plt.title('Daily Global Streams of popular songs 2017-2018')
sns.lineplot(data=df2)
# Out:
# <AxesSubplot:title={'center':'Daily Global Streams of popular songs 2017-2018'}, xlabel='Date'>

# %%
plt.figure(figsize=(14,6))
df2.rename(columns={'HUMBLE.':'HUMBLE'})
sns.lineplot(data=df2['Shape of You'], label='Shape of You')
sns.lineplot(data=df2['HUMBLE.'], label='HUMBLE')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Shape of You'>

# %%
plt.figure(figsize=(14,6))
plt.ylabel('.')
sns.lineplot(data=df1['BRA'])
sns.lineplot(data=df1['GER'])
# Out:
# <AxesSubplot:xlabel='Date', ylabel='.'>

# %%
# parte 3

# %%
df3=pd.read_csv('museum_visitors.csv',index_col='Date',parse_dates=True)

# %%
df3.head(10)
# Out:
#          Date  Avila Adobe  Firehouse Museum  Chinese American Museum  \
# 0  2014-01-01        24778              4486                     1581
# 1  2014-02-01        18976              4172                     1785
# 2  2014-03-01        25231              7082                     3229
# 3  2014-04-01        26989              6756                     2129
# 4  2014-05-01        36883             10858                     3676
# 5  2014-06-01        29487              5751                     2121
# 6  2014-07-01        32378              5406                     2239
# 7  2014-08-01        37680              8619                     1769
# 8  2014-09-01        28473             61192                     1073
# 9  2014-10-01        27995              6488                     1979
#
#    America Tropical Interpretive Center
# 0                                  6602
# 1                                  5029
# 2                                  8129
# ...

# %%
plt.figure(figsize=(16,6))
plt.ylabel('Number of Visitors')
sns.lineplot(data=df3)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Number of Visitors'>
